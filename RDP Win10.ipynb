# %%
#@title **Windows 10 Rdp**
#@markdown Sub: https://www.youtube.com/channel/UCPnpT-UiKwoawF1uvo1BC7w
# !wget https://bitbucket.org/hacktechlife/anothercompletevps/raw/1ef1c2f56d24cd5c42a74a9a0db49f078fc03925/lite10.sh > /dev/null 2>&1
# !chmod +x lite10.sh
# !./lite10.sh
# Out:
# Paste authtoken here (Copy and Ctrl+V to paste then press Enter): ^C
